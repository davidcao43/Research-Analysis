# %%
# Correlation matrix for numerical features
corr = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Correlation matrix for numerical features
# ----> 2 corr = df.corr()
#       3 plt.figure(figsize=(10,8))
#       4 sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 9. Correlation Analysis
# Compute and visualize correlations between housing prices and other numerical features, if available.

# %%
# Group by metro area and calculate average price
metro_avg = df.groupby('RegionName')['Zhvi'].mean().sort_values(ascending=False)

plt.figure(figsize=(14,6))
metro_avg.plot(kind='bar')
plt.title('Average Housing Price by Metro Area')
plt.xlabel('Metro Area')
plt.ylabel('Average ZHVI')
plt.xticks(rotation=90)
plt.show()

# Compare trends for top 5 metros
top_metros = metro_avg.head(5).index
for metro in top_metros:
    metro_df = df[df['RegionName'] == metro]
    plt.plot(metro_df['date_column'], metro_df['Zhvi'], label=metro)
plt.legend()
plt.title('Price Trends for Top 5 Metro Areas')
plt.xlabel('Date')
plt.ylabel('ZHVI')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 8. Analyze Price by Metro Area
# Group data by metro area and visualize average prices, trends, and compare metros.

# %%
# Histogram of housing prices
plt.figure(figsize=(10,6))
sns.histplot(df['Zhvi'], bins=30, kde=True)
plt.title('Distribution of Housing Prices (ZHVI)')
plt.xlabel('ZHVI')
plt.ylabel('Frequency')
plt.show()

# Boxplot by metro area
plt.figure(figsize=(14,8))
sns.boxplot(x='RegionName', y='Zhvi', data=df)
plt.title('Housing Price Distribution by Metro Area')
plt.xlabel('Metro Area')
plt.ylabel('ZHVI')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 7. Distribution of Housing Prices
# Create histograms or boxplots to show the distribution of housing prices across all metros.

# %%
# Example: Plot price trends for a selected metro area
# Replace 'RegionName' and 'date_column' with actual column names
selected_metro = df['RegionName'].unique()[0]
metro_df = df[df['RegionName'] == selected_metro]

plt.figure(figsize=(12,6))
plt.plot(metro_df['date_column'], metro_df['Zhvi'])
plt.title(f'Housing Price Trend Over Time: {selected_metro}')
plt.xlabel('Date')
plt.ylabel('ZHVI')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 6. Visualize Price Trends Over Time
# Plot time series graphs to visualize how housing prices change over months for selected metro areas.

# %%
# Descriptive statistics for numerical columns
df.describe()

# If price column is named differently, adjust below:
# df['price'].describe()

# %% [markdown]
# ## 5. Summary Statistics
# Generate descriptive statistics for housing prices and other relevant columns.

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_values[missing_values > 0]

# Optionally: Drop or fill missing values (example)
# df = df.dropna()  # or use df.fillna(method='ffill')

# %% [markdown]
# ## 4. Handle Missing Values
# Check for missing values and decide how to handle them.

# %%
# Display first few rows
df.head()

# Show column names and data types
df.info()

df.columns

# %% [markdown]
# ## 3. Inspect Data Structure
# Let's examine the first few rows, column names, and data types to understand the dataset.

# %%
# Load the housing price data
file_path = '../Data/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv'
df = pd.read_csv(file_path)
df.head()

# %% [markdown]
# ## 2. Load Housing Price Data
# Read the CSV file into a pandas DataFrame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization styles
sns.set(style="whitegrid")

# %% [markdown]
# ## 1. Import Required Libraries
# We will use pandas, numpy, matplotlib, and seaborn for data analysis and visualization.

# %% [markdown]
# # Exploratory Data Analysis (EDA) of Housing Price Data
#
# This notebook provides an exploratory analysis of the housing price dataset (`Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv`). The analysis follows the research proposal and covers data loading, inspection, cleaning, visualization, and insights.
